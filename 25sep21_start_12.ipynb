# %% [raw]
# Case Study II
# Domain – Retail
# focus – Visualize the sales data
# Business challenge/requirement
# BigMart is one of the biggest retailer of Europe and has operations across multiple countries. You are a data analyst in IT team of BigMart. Invoice and SKU wise Sales Data for Year 2011 is shared with you. You need to prepare meaningful charts to show case the various sales trends for 2011 to top management.
# Key issues
# Data should be displayed pictorially to capture the attention of top management
#
# Data volume
# - Approx 500K records – file BigMartSalesData.csv
# Additional information
# - NA
# Business benefits
# This exercise is an annual exercise and BigMart makes important investment decision based on trends
# Approach to Solve
# You have to use fundamentals of Matplotlib covered in module 5 and plot following 4 chart/graph
#
# 1. Plot Total Sales Per Month for Year 2011. How the total sales have increased over months in Year 2011. Which month has lowest Sales?
# 2. Plot Total Sales Per Month for Year 2011 as Bar Chart. Is Bar Chart Better to visualize than Simple Plot?
# 3. Plot Pie Chart for Year 2011 Country Wise. Which Country contributes highest towards sales?
# 4. Plot Scatter Plot for the invoice amounts and see the concentration of amount. In which range most of the invoice amounts are concentrated
# Enhancements for code
# You can try these enhancements in code
# 1. Change the bar chart to show the value of bar
# 2. In Pie Chart Play With Parameters shadow=True, startangle=90 and see how different the chart looks
# 3. In scatter plot change the color of Scatter Points

# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r'C:\D\Python_25Sep21\M7_dataset\983_m7_datasets_v1.0\BigMartSalesData.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID         Country
# 0       2.55   15.30    01-12-10    1     12  2010     17850.0  United Kingdom
# 1       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom
# 2       2.75   22.00    01-12-10    1     12  2010     17850.0  United Kingdom
# 3       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom
# 4       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom

# %%
#1. Plot Total Sales Per Month for Year 2011. How the total sales have increased over months in Year 2011. Which month has lowest Sales?

monthly_df = pd.DataFrame(df[df['Year']==2011].groupby('Month').sum()['Amount']).reset_index()
monthly_df
# Out:
#     Month       Amount
# 0       1   822669.640
# 1       2   549134.460
# 2       3   752003.310
# 3       4   582318.451
# 4       5   817655.200
# 5       6   832231.670
# 6       7   757108.941
# 7       8   791173.020
# 8       9  1097467.722
# 9      10  1239237.260
# 10     11  1557236.410
# 11     12   843909.020

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(monthly_df['Month'], monthly_df['Amount'])

# %%
#1. Plot Total Sales Per Month for Year 2011. How the total sales have increased over months in Year 2011. Which month has lowest Sales?

plt.plot(monthly_df['Month'], monthly_df['Amount'], marker='o')

# %%
# There is a steady increase by the second half of the year.
# Highest sales - November
# Lowest sales - February

# %%
# 2. Plot Total Sales Per Month for Year 2011 as Bar Chart. Is Bar Chart Better to visualize than Simple Plot?

plt.bar(data=monthly_df, x='Month', height = 'Amount')
# Out:
# <BarContainer object of 12 artists>

# %%
# 3. Plot Pie Chart for Year 2011 Country Wise. Which Country contributes highest towards sales?

country_df = pd.DataFrame(df[df['Year']==2011].groupby('Country').sum()['Amount']).astype(int).reset_index()
country_df
# Out:
#                  Country   Amount
# 0              Australia   138904
# 1                Austria     9945
# 2                Bahrain      754
# 3                Belgium    39671
# 4                 Brazil     1143
# 5                 Canada     3666
# 6        Channel Islands    20451
# 7                 Cyprus    12643
# 8         Czech Republic      945
# 9                Denmark    17861
# 10                  EIRE   292594
# 11    European Community     1308
# 12               Finland    21872
# 13                France   212369
# 14               Germany   220116
# 15                Greece     4810
# 16             Hong Kong    21266
# 17               Iceland     3598
# 18                Israel     8135
# 19                 Italy    17247
# 20                 Japan    31787
# 21               Lebanon     1693
# 22                 Malta     2945
# 23           Netherlands   277446
# 24                Norway    33380
# 25                Poland     7207
# 26              Portugal    35627
# 27                   RSA     1002
# 28          Saudi Arabia      160
# 29             Singapore    33438
# 30                 Spain    66535
# 31                Sweden    35138
# 32           Switzerland    56489
# 33                   USA     5429
# 34  United Arab Emirates     1902
# 35        United Kingdom  8997901
# 36           Unspecified     4749

# %%
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.pie(country_df['Amount'], labels=country_df['Country'], autopct='%.1f')
plt.show()

# %%
# United Kingdom has the highest sales contribution for year-2011

# %%
# 4. Plot Scatter Plot for the invoice amounts and see the concentration of amount. In which range most of the invoice amounts are concentrated

plt.scatter(x=df['Amount'], y=df['Amount'])

# %%
# more invoice amount are present in less than 25000 range

# %%
# You can try these enhancements in code
# 1. Change the bar chart to show the value of bar

month_summary = pd.DataFrame(df[df['Year']==2011].groupby('Month').sum()['Amount']).reset_index()
month_summary['Amount'] = month_summary['Amount'].apply(lambda x:round(x,1))
month_summary
# Out:
#     Month     Amount
# 0       1   822669.6
# 1       2   549134.5
# 2       3   752003.3
# 3       4   582318.5
# 4       5   817655.2
# 5       6   832231.7
# 6       7   757108.9
# 7       8   791173.0
# 8       9  1097467.7
# 9      10  1239237.3
# 10     11  1557236.4
# 11     12   843909.0

# %%
fig, ax = plt.subplots()    
width = 0.75 # the width of the bars 
ind = np.arange(len(month_summary['Amount']))  # the x locations for the groups
ax.barh(ind, month_summary['Amount'], width, color="blue")

for i, v in enumerate(month_summary['Amount']):
    ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')

# %%
# 2. In Pie Chart Play With Parameters shadow=True, startangle=90 and see how different the chart looks

fig = plt.gcf()
fig.set_size_inches(10,10)
plt.pie(country_df['Amount'], labels=country_df['Country'], autopct='%.1f', shadow=True, colors=['r','g','b'])
plt.show()

# %%
# 3. In scatter plot change the color of Scatter Points

plt.scatter(x=df['Amount'], y=df['Amount'], c='r')
