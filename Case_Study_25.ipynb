# %% [markdown]
# ## Module 10 - Case study 2

# %% [markdown]
# 1.Open and display the image “dog.jpeg”. Convert the image in to numpy array, so that i can be used in further processing.
#
# [Hint: Use PIL module from python]
#
# 2. Find out the dimensions of the image and convert it in to a two-dimensional array.
#
# 3.Use kmeans clustering with k set to 3 and cluster the image.
#
# [Hint: Refer to k-means module of scikit learn]
# 4. Predict the cluster label of every pixel in the image and plot it back as an image.
#
# 5. Find out the three dominant color in the image.
#
# [Hint: The cluster centers should correspond to three dominant colors]

# %%
from PIL import Image

# %% [markdown]
# 1. Open and display the image “dog.jpeg”. Convert the image in to numpy array, so that i can be used in further processing.

# %%
img = Image.open(r'D:\E\Courses\Edureka\Assignments\Dataset\module10\dogs.jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=272x185 at 0x234E3D9A0C8>

# %%
import numpy as np

img_arr = np.array(img)

# %%
img_arr
# Out:
# array([[[240, 240, 240],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[240, 240, 240],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[240, 240, 240],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[252, 248, 249],
#         [254, 250, 251],
#         [255, 253, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[247, 245, 246],
#         [250, 248, 249],
#         [255, 253, 254],
#         ...,
#         [255, 255, 255],
#         [252, 252, 252],
#         [244, 244, 244]],
#
#        [[253, 251, 254],
#         [253, 251, 254],
#         [253, 251, 252],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]]], dtype=uint8)

# %% [markdown]
# 2. Find out the dimensions of the image and convert it in to a two-dimensional array.

# %%
print(img_arr.shape)

# its a 3 dimentional array
# Out:
# (185, 272, 3)

# %%
img_arr_2d = img_arr.reshape((185*272, 3))
img_arr_2d
# Out:
# array([[240, 240, 240],
#        [255, 255, 255],
#        [255, 255, 255],
#        ...,
#        [254, 254, 254],
#        [254, 254, 254],
#        [254, 254, 254]], dtype=uint8)

# %% [markdown]
# 3. Use kmeans clustering with k set to 3 and cluster the image.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(img_arr_2d)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %% [markdown]
# 4. Predict the cluster label of every pixel in the image and plot it back as an image.

# %%
labels = kmeans.predict(img_arr_2d)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
labels = labels.reshape((185,272))
plt.imshow(labels)

# %% [markdown]
# 5. Find out the three dominant color in the image.

# %%
kmeans.cluster_centers_
# Out:
# array([[210.61955097, 174.81866601, 143.70526057],
#        [ 29.49800383,  21.57183484,  20.46825267],
#        [251.48731784, 247.68503858, 243.16040543]])
