# %% [markdown]
# # Module 6 - Case study 1

# %% [markdown]
# Questions:
#
# 1. Data Loading:
#
# a. Load the dataset “prisoners.csv” using pandas and display the first and last five rows in the dataset.
#
# [Hint: Refer to read_csv, head and tail methods in pandas]
#
# b. Use describe method in pandas and find out the number of columns. Can you say something about those rows who have zero inmates?
#
# [Hint: Use the loc attribute of dataframe combined with conditional checks]
#
# 2. Data Manipulation:
#
# a. Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.
#
# [Hint: Use sum method with appropriate axis]
#
# b. Create a new row - “totals” that is the sum of all inmates benefitted through each mode across all states.
#
# 3. Plotting:
# a. Make a bar plot with each state name on the x -axis and their total benefitted inmates as their bar heights. Which state has the maximum number of beneficiaries?
#
# [Hint: Use bar method of pyplot]
#
# b. Make a pie chart that depicts the ratio among different modes of benefits.
#
# [Hint: Use pie method of pyplot]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\sreeraj.va\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# 1. Data Loading:
#
# a. Load the dataset “prisoners.csv” using pandas and display the first and last five rows in the dataset.

# %%
df = pd.read_csv(r'D:\E\Courses\Edureka\Assignments\Dataset\module6\prisoners.csv')

# %%
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course
# 0                                           170
# 1                                             0
# 2                                            30
# 3                                          1417
# 4                                           103

# %%
df.tail()
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 30                                             0
# 31                                             0
# 32                                           174
# 33                                             0
# 34                                             0

# %% [markdown]
# b. Use describe method in pandas and find out the number of columns. Can you say something about those rows who have zero inmates?

# %%
df.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# 75%                                     1733.500000
# max                                    13758.000000
#
#        No. of Inmates benefitted by Higher Education  \
# count                                      35.000000
# mean                                      237.457143
# std                                       375.614191
# min                                         0.000000
# 25%                                         2.000000
# 50%                                        33.000000
# 75%                                       234.500000
# max                                      1353.000000
#
#        No. of Inmates benefitted by Computer Course
# count                                     35.000000
# mean                                     210.171429
# std                                      359.117340
# min                                        0.000000
# 25%                                        0.000000
# 50%                                       38.000000
# 75%                                      227.500000
# max                                     1417.000000

# %%
# states having zero inmates in different segments are below

df[(df['No. of Inmates benefitted by Adult Education'] == 0) | (df['No. of Inmates benefitted by Computer Course'] == 0) | (df['No. of Inmates benefitted by Elementary Education'] == 0) | (df['No. of Inmates benefitted by Higher Education'] == 0)]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 5                 Goa  2013
# 8    Himachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 5                                                   7
# 8                                                  33
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 28                                                167
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# 5                                              0
# 8                                             80
# 15                                             0
# 16                                            30
# 17                                            25
# 18                                             0
# 22                                             0
# 28                                            45
# 29                                           265
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 1                                               0
# 5                                               6
# 8                                              26
# 15                                              0
# 16                                              0
# 17                                             18
# 18                                              0
# 22                                              0
# 28                                             11
# 29                                             85
# 30                                              0
# 31                                              0
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 1                                              0
# 5                                             88
# 8                                              0
# 15                                             0
# 16                                             0
# 17                                             0
# 18                                             0
# 22                                             0
# 28                                             0
# 29                                             0
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0

# %%
# states having zero inmates in all segments are below

df[(df['No. of Inmates benefitted by Adult Education'] == 0) & (df['No. of Inmates benefitted by Computer Course'] == 0) & (df['No. of Inmates benefitted by Elementary Education'] == 0) & (df['No. of Inmates benefitted by Higher Education'] == 0)]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 18                                                  0
# 22                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# 15                                             0
# 18                                             0
# 22                                             0
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 1                                               0
# 15                                              0
# 18                                              0
# 22                                              0
# 30                                              0
# 31                                              0
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 1                                              0
# 15                                             0
# 18                                             0
# 22                                             0
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0

# %% [markdown]
# Data Manipulation:
#
# a. Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.

# %%
df['total_benefitted'] = df['No. of Inmates benefitted by Elementary Education'] + df['No. of Inmates benefitted by Adult Education'] + df['No. of Inmates benefitted by Higher Education'] + df['No. of Inmates benefitted by Computer Course']

# %%
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course  total_benefitted
# 0                                           170             24080
# 1                                             0                 0
# 2                                            30              1470
# 3                                          1417              6248
# 4                                           103              3762

# %% [markdown]
# b. Create a new row - “totals” that is the sum of all inmates benefitted through each mode across all states.

# %%
#method1

df.loc['Total',:] = df.sum(axis=0)

# %%
df.tail()
# Out:
#                                                 STATE/UT     YEAR  \
# 31                                           Daman & Diu   2013.0
# 32                                                 Delhi   2013.0
# 33                                           Lakshadweep   2013.0
# 34                                           Pondicherry   2013.0
# Total  Andhra PradeshArunachal PradeshAssamBiharChhat...  70455.0
#
#        No. of Inmates benefitted by Elementary Education  \
# 31                                                   0.0
# 32                                                1458.0
# 33                                                   0.0
# 34                                                   0.0
# Total                                            37027.0
#
#        No. of Inmates benefitted by Adult Education  \
# 31                                              0.0
# 32                                           1187.0
# 33                                              0.0
# 34                                              0.0
# Total                                       53720.0
#
#        No. of Inmates benefitted by Higher Education  \
# 31                                               0.0
# 32                                             908.0
# 33                                               0.0
# 34                                               0.0
# Total                                         8311.0
#
#        No. of Inmates benefitted by Computer Course  total_benefitted
# 31                                              0.0               0.0
# 32                                            174.0            3727.0
# 33                                              0.0               0.0
# 34                                              0.0               0.0
# Total                                        7356.0          106414.0

# %%
#method2

df = df.append(df.sum(numeric_only=True), ignore_index=True)

# %%
df.tail()
# Out:
#        STATE/UT     YEAR  No. of Inmates benefitted by Elementary Education  \
# 31  Daman & Diu   2013.0                                                0.0
# 32        Delhi   2013.0                                             1458.0
# 33  Lakshadweep   2013.0                                                0.0
# 34  Pondicherry   2013.0                                                0.0
# 35          NaN  70455.0                                            37027.0
#
#     No. of Inmates benefitted by Adult Education  \
# 31                                           0.0
# 32                                        1187.0
# 33                                           0.0
# 34                                           0.0
# 35                                       53720.0
#
#     No. of Inmates benefitted by Higher Education  \
# 31                                            0.0
# 32                                          908.0
# 33                                            0.0
# 34                                            0.0
# 35                                         8311.0
#
#     No. of Inmates benefitted by Computer Course  total_benefitted
# 31                                           0.0               0.0
# 32                                         174.0            3727.0
# 33                                           0.0               0.0
# 34                                           0.0               0.0
# 35                                        7356.0          106414.0

# %% [markdown]
# Plotting:
#
# a. Make a bar plot with each state name on the x -axis and their total benefitted inmates as their bar heights. Which state has the maximum number of beneficiaries?

# %%
df[['STATE/UT', 'total_benefitted']].iloc[:-1,:].set_index(['STATE/UT']).plot(kind='bar', figsize=(10,5), color='r')
plt.show()
plt.xlabel = 'STATE/UT'
plt.ylabel = 'Total benefited'

# %% [markdown]
# Andhra Pradesh has maximum beneficiaries.

# %% [markdown]
# b. Make a pie chart that depicts the ratio among different modes of benefits.

# %%
df2 = pd.read_csv(r'D:\E\Courses\Edureka\Assignments\Dataset\module6\prisoners.csv')
df2.loc['Total',:] = df2.sum()

# %%
df2_2 = df2.iloc[-1:,2:].T.reset_index()
df2_2.columns = ['mode', 'total_benefited']

# %%
df2_2
# Out:
#                                                 mode  total_benefited
# 0  No. of Inmates benefitted by Elementary Education          37027.0
# 1       No. of Inmates benefitted by Adult Education          53720.0
# 2      No. of Inmates benefitted by Higher Education           8311.0
# 3       No. of Inmates benefitted by Computer Course           7356.0

# %%
fig = plt.figure()
fig.set_size_inches(6,6)
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(df2_2['total_benefited'], labels=df2_2['mode'], startangle=90, radius=1.2)
plt.show()
